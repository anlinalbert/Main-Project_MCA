# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import ConvLSTM2D, LSTM
from keras.layers import Permute, Reshape
from keras.layers.convolutional import MaxPooling2D
from keras.layers.convolutional import Conv2D
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import metrics

# %%
# load a single file as a numpy array
def load_file(filepath):
    dataframe = read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = dstack(loaded)
    return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    print('File Path : ',filepath)
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load all train
X_train, Y_train = load_dataset_group('train', '/content/drive/MyDrive/MCA Main Project/UCI HAR/')
# load all test
X_test, Y_test = load_dataset_group('test', '/content/drive/MyDrive/MCA Main Project/UCI HAR/')

# zero-offset class values
Y_train = Y_train - 1
Y_test = Y_test - 1
# one hot encode y
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print('X_train.shape : ', X_train.shape)
print('Y_train.shape : ', Y_train.shape)
print('X_test.shape : ', X_test.shape)
print('Y_test.shape : ', Y_test.shape)
# Out:
# File Path :  /content/drive/MyDrive/MCA Main Project/UCI HAR/train/Inertial Signals/
# File Path :  /content/drive/MyDrive/MCA Main Project/UCI HAR/test/Inertial Signals/
# X_train.shape :  (7352, 128, 9)
# Y_train.shape :  (7352, 6)
# X_test.shape :  (2947, 128, 9)
# Y_test.shape :  (2947, 6)

# %%
n_timesteps = X_train.shape[1]
n_features = X_train.shape[2]
n_outputs = Y_train.shape[1]

# reshape into subsequences (samples, time steps, rows, cols, channels)
n_steps, n_length = 4, 32

X_train = X_train.reshape((X_train.shape[0], n_steps, 1, n_length, n_features))
X_test = X_test.reshape((X_test.shape[0], n_steps, 1, n_length, n_features))

# %%
verbose = 1
epochs = 30
batch_size = 20

# define model
model = Sequential()
model.add(ConvLSTM2D(filters=64, kernel_size=(1,3), activation='relu', input_shape=(n_steps, 1, n_length, n_features)))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit network
hist = model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_test, Y_test), batch_size=batch_size, verbose=verbose)

# evaluate model
(loss, accuracy) = model.evaluate(X_test, Y_test, batch_size=batch_size, verbose=verbose)
print("[INFO] loss={:.4f}, accuracy: {:.4f}%".format(loss, accuracy * 100))
# Out:
# Epoch 1/30
# 368/368 [==============================] - 28s 67ms/step - loss: 0.3929 - accuracy: 0.8437 - val_loss: 0.4032 - val_accuracy: 0.8789
# Epoch 2/30
# 368/368 [==============================] - 20s 55ms/step - loss: 0.1612 - accuracy: 0.9363 - val_loss: 0.4515 - val_accuracy: 0.8901
# Epoch 3/30
# 368/368 [==============================] - 23s 64ms/step - loss: 0.1237 - accuracy: 0.9478 - val_loss: 0.4723 - val_accuracy: 0.8792
# Epoch 4/30
# 368/368 [==============================] - 20s 56ms/step - loss: 0.1177 - accuracy: 0.9498 - val_loss: 0.5241 - val_accuracy: 0.9046
# Epoch 5/30
# 368/368 [==============================] - 23s 61ms/step - loss: 0.1215 - accuracy: 0.9505 - val_loss: 0.2926 - val_accuracy: 0.9053
# Epoch 6/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.1025 - accuracy: 0.9558 - val_loss: 0.3241 - val_accuracy: 0.9158
# Epoch 7/30
# 368/368 [==============================] - 20s 56ms/step - loss: 0.1001 - accuracy: 0.9561 - val_loss: 0.3850 - val_accuracy: 0.9138
# Epoch 8/30
# 368/368 [==============================] - 21s 58ms/step - loss: 0.1118 - accuracy: 0.9546 - val_loss: 0.3730 - val_accuracy: 0.9030
# Epoch 9/30
# 368/368 [==============================] - 21s 58ms/step - loss: 0.0999 - accuracy: 0.9550 - val_loss: 0.4427 - val_accuracy: 0.9050
# Epoch 10/30
# 368/368 [==============================] - 20s 56ms/step - loss: 0.0976 - accuracy: 0.9576 - val_loss: 1.2364 - val_accuracy: 0.7886
# Epoch 11/30
# 368/368 [==============================] - 20s 54ms/step - loss: 0.1122 - accuracy: 0.9565 - val_loss: 0.3470 - val_accuracy: 0.9189
# Epoch 12/30
# 368/368 [==============================] - 20s 54ms/step - loss: 0.0821 - accuracy: 0.9648 - val_loss: 0.4103 - val_accuracy: 0.9192
# Epoch 13/30
# 368/368 [==============================] - 21s 57ms/step - loss: 0.0815 - accuracy: 0.9650 - val_loss: 0.5783 - val_accuracy: 0.9009
# Epoch 14/30
# 368/368 [==============================] - 22s 59ms/step - loss: 0.0839 - accuracy: 0.9630 - val_loss: 0.3944 - val_accuracy: 0.9186
# Epoch 15/30
# 368/368 [==============================] - 21s 57ms/step - loss: 0.0697 - accuracy: 0.9678 - val_loss: 0.4990 - val_accuracy: 0.9145
# Epoch 16/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0688 - accuracy: 0.9684 - val_loss: 0.7405 - val_accuracy: 0.9152
# Epoch 17/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0578 - accuracy: 0.9736 - val_loss: 0.5895 - val_accuracy: 0.9196
# Epoch 18/30
# 368/368 [==============================] - 23s 61ms/step - loss: 0.0547 - accuracy: 0.9763 - val_loss: 0.5916 - val_accuracy: 0.9036
# Epoch 19/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0653 - accuracy: 0.9747 - val_loss: 0.5027 - val_accuracy: 0.9033
# Epoch 20/30
# 368/368 [==============================] - 21s 58ms/step - loss: 0.0512 - accuracy: 0.9758 - val_loss: 0.4900 - val_accuracy: 0.9060
# Epoch 21/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0776 - accuracy: 0.9724 - val_loss: 0.5580 - val_accuracy: 0.8873
# Epoch 22/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0579 - accuracy: 0.9767 - val_loss: 0.3993 - val_accuracy: 0.9043
# Epoch 23/30
# 368/368 [==============================] - 25s 68ms/step - loss: 0.0463 - accuracy: 0.9793 - val_loss: 0.4894 - val_accuracy: 0.9114
# Epoch 24/30
# 368/368 [==============================] - 24s 64ms/step - loss: 0.0468 - accuracy: 0.9778 - val_loss: 0.4841 - val_accuracy: 0.9070
# Epoch 25/30
# 368/368 [==============================] - 20s 56ms/step - loss: 0.0466 - accuracy: 0.9805 - val_loss: 0.5523 - val_accuracy: 0.8992
# Epoch 26/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0447 - accuracy: 0.9797 - val_loss: 0.5881 - val_accuracy: 0.9128
# Epoch 27/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0442 - accuracy: 0.9814 - val_loss: 0.4927 - val_accuracy: 0.9033
# Epoch 28/30
# 368/368 [==============================] - 21s 57ms/step - loss: 0.0368 - accuracy: 0.9838 - val_loss: 0.6151 - val_accuracy: 0.9111
# Epoch 29/30
# 368/368 [==============================] - 21s 58ms/step - loss: 0.0340 - accuracy: 0.9846 - val_loss: 0.5504 - val_accuracy: 0.9087
# Epoch 30/30
# 368/368 [==============================] - 21s 56ms/step - loss: 0.0334 - accuracy: 0.9835 - val_loss: 0.6300 - val_accuracy: 0.9074
# 148/148 [==============================] - 2s 13ms/step - loss: 0.6300 - accuracy: 0.9074
# [INFO] loss=0.6300, accuracy: 90.7363%

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 1, 30, 64)         56320
#
#  dropout (Dropout)           (None, 1, 30, 64)         0
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dense (Dense)               (None, 128)               245888
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 302,982
# Trainable params: 302,982
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Print confusion matrix for training data
y_pred_train = model.predict(X_train)
# Take the class with the highest probability from the train predictions
max_y_pred_train = np.argmax(y_pred_train, axis=1)
#print(classification_report(trainy, max_y_pred_train))

# confusion matrix
LABELS = ['WALKING',
          'WALKING_UPSTAIRS',
          'WALKING_DOWNSTAIRS',
          'SITTING',
          'STANDING',
          'LAYING']
y_pred_test = model.predict(X_test)
# Take the class with the highest probability from the test predictions
max_y_pred_test = np.argmax(y_pred_test, axis=1)
max_y_test = np.argmax(Y_test, axis=1)

matrix = metrics.confusion_matrix(max_y_test, max_y_pred_test)
plt.figure(figsize=(6, 4))
sns.heatmap(matrix,
            cmap='PiYG_r',
            linecolor='white',
            linewidths=1,
            xticklabels=LABELS,
            yticklabels=LABELS,
            annot=True,
            fmt='d')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
